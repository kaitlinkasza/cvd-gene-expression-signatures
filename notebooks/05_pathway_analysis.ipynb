# %%
import pandas as pd
import gseapy as gp

sig = pd.read_csv(
    "../outputs/tables/significant_genes.csv"
)

gene_list = sig["gene"].dropna().astype(str).tolist()

print(gene_list[:10])
print(len(gene_list))

enr = gp.enrichr(
    gene_list=gene_list,
    gene_sets="KEGG_2021_Human",
    organism="human"
)

enr.results.head()
# Out:
# []
# 0
# ---------------------------------------------------------------------------
# EnrichrValidationError                    Traceback (most recent call last)
# Cell In[15], line 13
#      10 print(gene_list[:10])
#      11 print(len(gene_list))
# ---> 13 enr = gp.enrichr(
#      14     gene_list=gene_list,
#      15     gene_sets="KEGG_2021_Human",
#      16     organism="human"
#      17 )
#      19 enr.results.head()
#
# File ~/cvd-gene-expression-signatures/venv/lib/python3.10/site-packages/gseapy/__init__.py:581, in enrichr(gene_list, gene_sets, organism, outdir, background, cutoff, format, figsize, top_term, no_plot, verbose)
#     579 # set organism
#     580 enr.set_organism()
# --> 581 enr.run()
#     583 return enr
#
# File ~/cvd-gene-expression-signatures/venv/lib/python3.10/site-packages/gseapy/enrichr.py:785, in Enrichr.run(self)
#     783 """Run enrichr for one sample gene list against multiple libraries."""
#     784 # Validate inputs
# ...
